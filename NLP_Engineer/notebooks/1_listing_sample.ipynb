# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/cleaned_listing_full.csv")
df.head()
# Out:
#    L_ListingID                 L_Address         L_City  beds  baths    price  \
# 0   1118422731           1461 Laurel Way  Beverly Hills   4.0    5.0  3950000
# 1   1118417283  13545 Surcease Mine Road       Oroville   3.0    1.0   199000
# 2   1118405579       31499 Via Las Rosas  Carmel Valley   4.0    3.0  2890000
# 3   1118398412           582 Pasture Ave        Lathrop   4.0    3.0   775000
# 4   1119757884        13679 Calle Romano        Tijuana   3.0    4.0   480000
#
#      sqft                                            remarks  \
# 0  3677.0  Opportunity to reimagine a Classic 70's Archit...
# 1   950.0  Gated Privacy with views of Lake Oroville.  Th...
# 2  2826.0  Your search ends here.  This spectacular prope...
# 3  2709.0  Step into comfort and functionality with this ...
# 4  2637.0  Introducing Helena Residences, an exclusive de...
#
#                                      cleaned_remarks
# 0  Opportunity to reimagine a Classic 70's Archit...
# ...

# %%
df.isna().sum()
# Out:
# L_ListingID          0
# L_Address          114
# L_City              92
# beds               101
# baths               17
# price                0
# sqft                83
# remarks              0
# cleaned_remarks      0
# dtype: int64
